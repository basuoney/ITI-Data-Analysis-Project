# %%
# ---------------------------------------
# PART 1: Setup & Test Reading a CSV File
# ---------------------------------------

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T

spark = SparkSession.builder.getOrCreate()

print("Spark session started")
# Out:
# StatementMeta(, 50a483ea-f96a-48fe-8ae3-05ae328d0975, 28, Finished, Available, Finished)
# Spark session started

# %%
# ======================================================
# PART 2 — Student folders + Safe CSV loader + Record template
# ======================================================

from pyspark.sql.utils import AnalysisException

# ------------------------------------------------------
# 1. List of student folders (based on your Lakehouse)
# ------------------------------------------------------
students = [
    "Ahmed",
    "Aya",
    "Manar",
    "Mennatullah",
    "Mohamed Elbasuoney"
]

print("Students detected:", students)

# ------------------------------------------------------
# 2. Safe CSV Loader Function
# ------------------------------------------------------
def load_csv_safe(path):
    """
    Safely loads a CSV file.
    Returns None if file does not exist or fails to load.
    """
    try:
        df = spark.read.csv(path, header=True, inferSchema=True)
        if df.count() == 0:
            return None
        return df
    except Exception:
        return None

# ------------------------------------------------------
# 3. Initialize student record dictionary
# (Matches exactly the final table schema)
# ------------------------------------------------------
student_records = []

for student in students:

    record = {
        "StudentFolder": student,
        "FullName": None,
        "Email": None,
        "Headline": None,
        "Summary": None,
        "Skills": None,
        "Certifications": None,
        "Education": None,
        "ConnectionsCount": None,
        "InvitationsCount": None,
        "ProfilePhotoUrl": None,
        "BackgroundPhotoUrl": None,
        "HeaderPhotoUrl": None
    }

    student_records.append(record)

student_records
# Out:
# StatementMeta(, 50a483ea-f96a-48fe-8ae3-05ae328d0975, 29, Finished, Available, Finished)
# Students detected: ['Ahmed', 'Aya', 'Manar', 'Mennatullah', 'Mohamed Elbasuoney']
# [{'StudentFolder': 'Ahmed',
#   'FullName': None,
#   'Email': None,
#   'Headline': None,
#   'Summary': None,
#   'Skills': None,
#   'Certifications': None,
#   'Education': None,
#   'ConnectionsCount': None,
#   'InvitationsCount': None,
#   'ProfilePhotoUrl': None,
#   'BackgroundPhotoUrl': None,
#   'HeaderPhotoUrl': None},
#  {'StudentFolder': 'Aya',
#   'FullName': None,
#   'Email': None,
#   'Headline': None,
#   'Summary': None,
#   'Skills': None,
#   'Certifications': None,
#   'Education': None,
#   'ConnectionsCount': None,
#   'InvitationsCount': None,
#   'ProfilePhotoUrl': None,
#   'BackgroundPhotoUrl': None,
#   'HeaderPhotoUrl': None},
#  {'StudentFolder': 'Manar',
#   'FullName': None,
#   'Email': None,
#   'Headline': None,
#   'Summary': None,
#   'Skills': None,
#   'Certifications': None,
#   'Education': None,
#   'ConnectionsCount': None,
#   'InvitationsCount': None,
#   'ProfilePhotoUrl': None,
#   'BackgroundPhotoUrl': None,
#   'HeaderPhotoUrl': None},
#  {'StudentFolder': 'Mennatullah',
#   'FullName': None,
#   'Email': None,
#   'Headline': None,
#   'Summary': None,
#   'Skills': None,
#   'Certifications': None,
#   'Education': None,
#   'ConnectionsCount': None,
#   'InvitationsCount': None,
#   'ProfilePhotoUrl': None,
#   'BackgroundPhotoUrl': None,
#   'HeaderPhotoUrl': None},
#  {'StudentFolder': 'Mohamed Elbasuoney',
#   'FullName': None,
#   'Email': None,
#   'Headline': None,
#   'Summary': None,
#   'Skills': None,
#   'Certifications': None,
#   'Education': None,
#   'ConnectionsCount': None,
#   'InvitationsCount': None,
#   'ProfilePhotoUrl': None,
#   'BackgroundPhotoUrl': None,
#   'HeaderPhotoUrl': None}]

# %%
# ======================================================
# PART 3 — Extract Profile.csv fields (FullName, Headline, Summary)
# ======================================================

for record in student_records:

    student = record["StudentFolder"]
    path_profile = f"Files/profiles/{student}/Profile.csv"

    print(f"\nProcessing Profile.csv for: {student}")

    df_profile = load_csv_safe(path_profile)

    if df_profile is None:
        print("  -> Profile.csv NOT FOUND")
        continue

    # Extract column names
    cols = df_profile.columns
    row = df_profile.first()

    # ------------------------------------------------------
    # FULL NAME
    # ------------------------------------------------------
    if "First Name" in cols and "Last Name" in cols:
        record["FullName"] = f"{row['First Name']} {row['Last Name']}"
    elif "Name" in cols:
        record["FullName"] = row["Name"]

    # ------------------------------------------------------
    # HEADLINE
    # ------------------------------------------------------
    if "Headline" in cols:
        record["Headline"] = row["Headline"]

    # ------------------------------------------------------
    # SUMMARY
    # ------------------------------------------------------
    if "Summary" in cols:
        record["Summary"] = row["Summary"]

    print("  -> FullName:", record["FullName"])
    print("  -> Headline:", record["Headline"])
    print("  -> Summary OK")
# Out:
# StatementMeta(, 50a483ea-f96a-48fe-8ae3-05ae328d0975, 30, Finished, Available, Finished)
# Processing Profile.csv for: Ahmed
#   -> FullName: Ahmed Salah
#   -> Headline: Microsoft Certified: Power BI Data Analyst Associate (PL-300) | Power BI Developer | Junior Data Analyst | SQL | Excel | Python
#   -> Summary OK
#
# Processing Profile.csv for: Aya
#   -> FullName: Aya Fathy
#   -> Headline: Power BI Developer Trainee @ITI l Junior Data Analyst l Edu Mentor @iSchool l ExTeaching Assistant @ Pharos University
#   -> Summary OK
#
# Processing Profile.csv for: Manar
#   -> FullName: Manar Elmslmany
#   -> Headline: Power BI Developer Trainee @ ITI | Junior Data Analyst
#   -> Summary OK
#
# Processing Profile.csv for: Mennatullah
#   -> FullName: Menna Hamed
#   -> Headline: Computer and information technology graduated| Power BI Developer Trainee at ITI| Data Analysis & Freelancing Graduate – NTI | Digital Egypt Pioneers Trainee in power bi developer track
#   -> Summary OK
#
# Processing Profile.csv for: Mohamed Elbasuoney
#   -> FullName: Mohamed Elbasuoney
#   -> Headline: Statistical Analyst @ GOTHI | Youth Ambassador @ IOM | Data Analyst | ITI | Research | ALX | Digital Health | Climate Advocate
#   -> Summary OK

# %%
# ======================================================
# PART 4 — Extract Skills, Certifications, Education
# ======================================================

for record in student_records:

    student = record["StudentFolder"]
    base = f"Files/profiles/{student}"

    print(f"\nExtracting data for: {student}")

    # ======================================================
    # 1. SKILLS.csv
    # ======================================================
    df_skills = load_csv_safe(f"{base}/Skills.csv")

    if df_skills is not None:
        skill_cols = df_skills.columns
        
        # Find skill-like column
        skill_col = None
        for c in skill_cols:
            if "skill" in c.lower() or "name" in c.lower():
                skill_col = c
                break

        if skill_col:
            skills_list = (
                df_skills.select(skill_col)
                         .dropna()
                         .rdd.flatMap(lambda x: x)
                         .collect()
            )
            if skills_list:
                record["Skills"] = ", ".join([str(s) for s in skills_list])

        print("  -> Skills extracted")

    # ======================================================
    # 2. CERTIFICATIONS.csv
    # ======================================================
    df_cert = load_csv_safe(f"{base}/Certifications.csv")

    if df_cert is not None:
        cert_cols = df_cert.columns
        
        # Find certification-like column
        cert_col = None
        for c in cert_cols:
            if "cert" in c.lower() or "name" in c.lower():
                cert_col = c
                break

        if cert_col:
            cert_list = (
                df_cert.select(cert_col)
                       .dropna()
                       .rdd.flatMap(lambda x: x)
                       .collect()
            )
            if cert_list:
                record["Certifications"] = " | ".join([str(c) for c in cert_list])

        print("  -> Certifications extracted")

    # ======================================================
    # 3. EDUCATION.csv
    # ======================================================
    df_edu = load_csv_safe(f"{base}/Education.csv")

    if df_edu is not None:
        edu_cols = df_edu.columns
        
        # Columns vary in LinkedIn — detect dynamically
        school_col = next((c for c in edu_cols if "school" in c.lower()), None)
        degree_col = next((c for c in edu_cols if "degree" in c.lower()), None)
        field_col  = next((c for c in edu_cols if "field" in c.lower() or "study" in c.lower()), None)

        edu_entries = []

        for row in df_edu.collect():
            parts = []

            if school_col and row[school_col] not in (None, "nan"):
                parts.append(str(row[school_col]))

            if degree_col and row[degree_col] not in (None, "nan"):
                parts.append(str(row[degree_col]))

            if field_col and row[field_col] not in (None, "nan"):
                parts.append(str(row[field_col]))

            if parts:
                edu_entries.append(" - ".join(parts))

        if edu_entries:
            record["Education"] = " | ".join(edu_entries)

        print("  -> Education extracted")
# Out:
# StatementMeta(, 50a483ea-f96a-48fe-8ae3-05ae328d0975, 31, Finished, Available, Finished)
# Extracting data for: Ahmed
#   -> Skills extracted
#   -> Certifications extracted
#   -> Education extracted
#
# Extracting data for: Aya
#   -> Skills extracted
#   -> Certifications extracted
#   -> Education extracted
#
# Extracting data for: Manar
#   -> Skills extracted
#   -> Education extracted
#
# Extracting data for: Mennatullah
#   -> Skills extracted
#   -> Education extracted
#
# Extracting data for: Mohamed Elbasuoney
#   -> Skills extracted
#   -> Certifications extracted
#   -> Education extracted

# %%
# ======================================================
# PART 5 — Email + Rich Media + Counts + Save Final Table
# ======================================================

for record in student_records:

    student = record["StudentFolder"]
    base = f"Files/profiles/{student}"

    print(f"\nExtracting email and media for: {student}")

    # ======================================================
    # 1. EMAIL (Fixed Logic)
    # ======================================================
    df_email = load_csv_safe(f"{base}/Email Addresses.csv")

    if df_email is not None and "Email Address" in df_email.columns:

        # Normalize column names
        df_email = df_email.withColumnRenamed("Email Address", "EmailAddress") \
                           .withColumnRenamed("Primary", "PrimaryFlag")

        # Prefer Primary = "Yes"
        primary_df = df_email.filter(F.col("PrimaryFlag") == "Yes")

        if primary_df.count() > 0:
            record["Email"] = primary_df.first()["EmailAddress"]
        else:
            # fallback: first email
            record["Email"] = df_email.first()["EmailAddress"]

    # ======================================================
    # 2. Connections Count
    # ======================================================
    df_conn = load_csv_safe(f"{base}/Connections.csv")
    if df_conn is not None:
        record["ConnectionsCount"] = df_conn.count()

    # ======================================================
    # 3. Invitations Count
    # ======================================================
    df_inv = load_csv_safe(f"{base}/Invitations.csv")
    if df_inv is not None:
        record["InvitationsCount"] = df_inv.count()

    # ======================================================
    # 4. Rich Media (Profile Photo + Background + Header)
    # ======================================================
    df_media = load_csv_safe(f"{base}/Rich_Media.csv")

    if df_media is not None and "Media Link" in df_media.columns:

        links = (
            df_media.select("Media Link")
                    .dropna()
                    .rdd.flatMap(lambda x: x)
                    .collect()
        )

        # --- Profile Photo ---
        profile_candidates = [
            url for url in links
            if "profile-displayphoto" in url.lower()
            or "profile-originalphoto" in url.lower()
        ]
        record["ProfilePhotoUrl"] = profile_candidates[0] if profile_candidates else None

        # --- Background Photo ---
        bg_candidates = [
            url for url in links
            if "profile-displaybackgroundimage" in url.lower()
            or "profile-originalbackgroundimage" in url.lower()
        ]
        record["BackgroundPhotoUrl"] = bg_candidates[0] if bg_candidates else None

        # --- Header Photo = first row in CSV ---
        record["HeaderPhotoUrl"] = df_media.first()["Media Link"]

        print("  -> Profile Photo:", record["ProfilePhotoUrl"])
        print("  -> Background Photo:", record["BackgroundPhotoUrl"])
        print("  -> Header Photo:", record["HeaderPhotoUrl"])


# ======================================================
# PART 5 — Final Schema + Save Delta Table
# ======================================================

from pyspark.sql.types import StructType, StructField, StringType, IntegerType

schema = StructType([
    StructField("StudentFolder",      StringType(),  True),
    StructField("FullName",           StringType(),  True),
    StructField("Email",              StringType(),  True),
    StructField("Headline",           StringType(),  True),
    StructField("Summary",            StringType(),  True),
    StructField("Skills",             StringType(),  True),
    StructField("Certifications",     StringType(),  True),
    StructField("Education",          StringType(),  True),
    StructField("ConnectionsCount",   IntegerType(), True),
    StructField("InvitationsCount",   IntegerType(), True),
    StructField("ProfilePhotoUrl",    StringType(),  True),
    StructField("BackgroundPhotoUrl", StringType(),  True),
    StructField("HeaderPhotoUrl",     StringType(),  True)
])

df_final = spark.createDataFrame(student_records, schema=schema)

print("\nFinal DataFrame:")
df_final.show(truncate=False)

df_final.write.mode("overwrite").format("delta").saveAsTable("LinkedProfiles")

print("\nLinkedProfiles table saved successfully!")
# Out:
# StatementMeta(, 50a483ea-f96a-48fe-8ae3-05ae328d0975, 32, Finished, Available, Finished)
# Extracting email and media for: Ahmed
#   -> Profile Photo: https://media.licdn.com/dms/image/v2/D4D04AQFosDDlow4xaA/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1733952079261?e=1765411200&v=beta&t=S6wjTIWLq63B-Q1hhd3B0Gk5ARUefCrRBzOjtc7g2Wk
#   -> Background Photo: https://media.licdn.com/dms/image/v2/D4D16AQFWzt49NgejSA/profile-displaybackgroundimage-shrink_200_800/B4DZVrhKWZHIAY-/0/1741265613584?e=1765411200&v=beta&t=fq4ONxgEYE4kSkF-gBq1RjUXJqCJqdNC1NeRfB1mecY
#   -> Header Photo: https://media.licdn.com/dms/document/media/v2/D4D2DAQHpCWyEfsvAlg/profile-treasury-document-chunked-pdf/B4DZhNcMxwHwBg-/0/1753645900810?e=1764363600&v=beta&t=jzraeAA7Z_RGRs1jCR9S4VH-o8UYjTGlZpL03q6zO4M
#
# Extracting email and media for: Aya
#   -> Profile Photo: https://media.licdn.com/dms/image/v2/D4D04AQEb6S2x3zLMSQ/profile-originalphoto-shrink_900_1200/B4DZiOcp_nH8AI-/0/1754736536065?e=1765411200&v=beta&t=AgR7-yIBigEwqlgtZXhcEoGf6o1qcBAaKocTnBVUziA
#   -> Background Photo: None
#   -> Header Photo: https://media.licdn.com/dms/image/v2/D4D22AQF5d-ZWB1Iklw/feedshare-shrink_1280/B4DZp3lXwEGgAw-/0/1762942878565?e=1765411200&v=beta&t=mquL2pD8hM3Pupi9bsFtEru1Dk7TdyI_TKBq0w1-fJE
#
# Extracting email and media for: Manar
#   -> Profile Photo: https://media.licdn.com/dms/image/v2/C4D04AQEjjrT30xAgqg/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1651110268551?e=1765411200&v=beta&t=3Je2EuQR8vgthnDcKw6NBqaF8HF27wHN44axH4gr4e8
#   -> Background Photo: None
#   -> Header Photo: https://media.licdn.com/dms/document/media/v2/D4D1FAQH6aq2hUHCXqQ/feedshare-document-chunked-pdf/B4DZjc9..oGgBo-/0/1756053912680?e=1764345600&v=beta&t=jyDH0jk0xBxhpHwRU5Xfua7MYMQI0Nj1eeWvCmNCj4g
#
# Extracting email and media for: Mennatullah
#   -> Profile Photo: https://media.licdn.com/dms/image/v2/D4E04AQEACjRSg_eGeg/profile-originalphoto-shrink_900_1200/B4EZpQZM.eHgAI-/0/1762285377149?e=1765411200&v=beta&t=6a2ttJV8hYKewc5HDeQqqyRzLfLeQgAFv26JnxYdhvc
#   -> Background Photo: https://media.licdn.com/dms/image/v2/D4E04AQG69PAa1eMnyQ/profile-originalbackgroundimage-shrink_396_1584/B4EZUlXkmdHMAQ-/0/1740088692821?e=1765411200&v=beta&t=Z-aQH1SVE3t9wMTbR-q_S1e2ccGAJM1DpoQSCEBpfNY
#   -> Header Photo: https://media.licdn.com/dms/image/v2/D4E04AQEACjRSg_eGeg/profile-originalphoto-shrink_900_1200/B4EZpQZM.eHgAI-/0/1762285377149?e=1765411200&v=beta&t=6a2ttJV8hYKewc5HDeQqqyRzLfLeQgAFv26JnxYdhvc
#
# Extracting email and media for: Mohamed Elbasuoney
#   -> Profile Photo: https://media.licdn.com/dms/image/v2/D4D04AQHnibNjP1Em7A/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1731011376131?e=1765411200&v=beta&t=3NDTCyYkKDFNVWkCkYFXOaJwBdbl5Cyd_wZogNE6-sQ
#   -> Background Photo: https://media.licdn.com/dms/image/v2/D4D16AQF13l8GCJAFBg/profile-displaybackgroundimage-shrink_200_800/profile-displaybackgroundimage-shrink_200_800/0/1722788861229?e=1765411200&v=beta&t=8j6Op6iGbUD5BRAJww-psklyIyWc-2qx9TQGIjx9hCk
#   -> Header Photo: https://media.licdn.com/dms/document/media/v2/D4D2DAQFGTYy2mLBD3w/profile-treasury-document-pdf-analyzed/B4DZpAmm4eJcAg-/0/1762020465760?e=1764374400&v=beta&t=1PkFlXu4hqMN6HRn5qPKKXjmGkS7fFZd8W4Se1LQk8E
#
# Final DataFrame:
# +------------------+------------------+------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------- ...
# |StudentFolder     |FullName          |Email                   |Headline                                                                                                                                                                                 |Summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |Certifications                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |Education                                                                                                                                                                                  |ConnectionsCount|InvitationsCount|ProfilePhotoUrl                                                                                                                                                                                                       |BackgroundPhotoUrl            ...
# +------------------+------------------+------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------- ...
# |Ahmed             |Ahmed Salah       |sabo62153@gmail.com     |Microsoft Certified: Power BI Data Analyst Associate (PL-300) | Power BI Developer | Junior Data Analyst | SQL | Excel | Python                                                          |A data-driven professional with a strong background in Business Intelligence and Data Analytics, holding the Microsoft Certified: Power BI Data Analyst Associate (PL-300) certification. I am a proud graduate of the ITI Power BI Developer Track and the Data-X Diploma, where I gained deep hands-on experience in analyzing, modeling, and visualizing data across multiple business domains.  Throughout my journey, I have worked on numerous projects using Power BI, developing dynamic dashboards, data models, and DAX-based insights that drive smarter decisions. I also bring strong expertise in Excel (Power Pivot, Power Query, DAX, Cube Functions, Data Modeling) and have solid experience in Tableau for advanced visual storytelling.  My technical foundation also extends to SQL-BI tools (SSIS, SSAS, SSRS) — enabling me to manage data workflows end-to-end and deliver complete business intelligence solutions.  In addition, I’ve successfully completed several freelance projects on Upwork, collaborating with international clients and helping them uncover valuable insights through clean, structured, and interactive data solutions.  Driven by curiosity and continuous learning, I’m passionate about transforming raw data into meaningful insights that add measurable value and fuel innovation. My Portfolio: https://sites.google.com/view/ahmedsalah1488/home|Data Cleaning,  Pivot Tables,    Power Bi,     Power Query, Microsoft SQL Server, Microsoft Excel, تحليل البيانات, تحليل البيانات الإحصائية, Social media design , Illustration, Graphic design , Graphic designer , Machine Learning , Training , Team Work , Python, Communication , Research , Biomedical engineering , English, Education, Introduction to Tensor Flow For Artificial Intelligence, Machine Learning                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | Practical Machine Learning for Data Scientists | Business Analytics with Excel | Power BI for Beginners | Google Sheets | Database Fundamentals | SQL (Basic) Certificate | Data-X Diploma Certificate  | Python Programming Certificate | Oracle Cloud Database Services 2025 Certified Professional | ChatGPT for Data Analytics | Microsoft Excel Foundations | Advanced SQL Querying | Thinking Like an Analyst | Power BI Desktop | Microsoft Certified: Power BI Data Analyst Associate                                                                                                                                                                                  |Mansoura University - بكالوريوس الهندسة                                                                                                                                                    |3018            |563             |https://media.licdn.com/dms/image/v2/D4D04AQFosDDlow4xaA/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1733952079261?e=1765411200&v=beta&t=S6wjTIWLq63B-Q1hhd3B0Gk5ARUefCrRBzOjtc7g2Wk|https://media.licdn.com/dms/i ...
# |Aya               |Aya Fathy         |aya2.fathy123@gmail.com |Power BI Developer Trainee @ITI l Junior Data Analyst l Edu Mentor @iSchool l ExTeaching Assistant @ Pharos University                                                                   |My Name is Aya Fathy ,I am junior data analyst with expertise in transforming complex data into actionable and meaningful insights. Skilled in SQL, Python, Excel, Tableau, and Power BI, with a strong foundation in statistical analysis and data visualization. Passionate about uncovering trends, optimizing business processes, and driving data-informed decision-making. Experienced in cleaning, analyzing, and interpreting large datasets to support strategic initiatives. Strong communicator with the ability to present findings clearly to stakeholders at all levels.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |Analytical Skills, Business Analysis, Strategic Thinking, PostgreSQL, Statistics, NumPy, Extract, Transform, Load (ETL), Microsoft Power Query, SQL, Tableau, Educational Consulting, Educational Leadership, Management, Leadership, Data Modeling, Microsoft Power BI, DAX, perparing data, Data Transformation, Data Transfer, Microsoft Excel, Data Analysis, Data Visualization, Python (Programming Language), Working with Children and The Youth , Software Development, Teamwork, Teaching, Communication and Teamwork , Multitasking, Flutter, Presentation Skills, Problem Solving, Computer Science, Microsoft SQL Server, MySQL, Databases, C++, Flutter Developer , Programming, Java, Dart                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |Flutter Development Diploma  | Introduction to Data and Data Science  | Introduction to Excel | Preparing Data for Analysis with Microsoft Excel | Harnessing the Power of Data with Power BI | Databse Fundamentals  | Extract ,Transform and Load Data In Power BI | Introduction to Python | Associate Data Analyst | Think Like Data Analyst | Data Modeling in Power BI                                                                                                                                                                                                                                                                                                    |Faculty of computers and information system Damnhour University  - Bachelor's degree | Information Technology Institute (ITI) - Power BI Development                                       |1515            |554             |https://media.licdn.com/dms/image/v2/D4D04AQEb6S2x3zLMSQ/profile-originalphoto-shrink_900_1200/B4DZiOcp_nH8AI-/0/1754736536065?e=1765411200&v=beta&t=AgR7-yIBigEwqlgtZXhcEoGf6o1qcBAaKocTnBVUziA                      |NULL                          ...
# |Manar             |Manar Elmslmany   |manarelmslmany@gmail.com|Power BI Developer Trainee @ ITI | Junior Data Analyst                                                                                                                                   |Data analysis plays a crucial role in your project. If you’re ready to take a powerful step forward in your business, start by analyzing your existing data.  What can I do:  - Analyse data with the most important insights   to help you make the best decisions.  - Build interactive dashboards that make it easy for you to read the results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |Data Visualization, Data Analysis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |NULL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |Alexandria University - Bachelor's degree                                                                                                                                                  |574             |379             |https://media.licdn.com/dms/image/v2/C4D04AQEjjrT30xAgqg/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1651110268551?e=1765411200&v=beta&t=3Je2EuQR8vgthnDcKw6NBqaF8HF27wHN44axH4gr4e8|NULL                          ...
# |Mennatullah       |Menna Hamed       |hamedmenna831@gmail.com |Computer and information technology graduated| Power BI Developer Trainee at ITI| Data Analysis & Freelancing Graduate – NTI | Digital Egypt Pioneers Trainee in power bi developer track|I am a passionate and detail-oriented individual with a focus on Data Analysis, skilled in transforming complex datasets into clear, impactful stories. My expertise lies in Python, SQL, excel, and Power BI, coupled with a solid foundation in statistical analysis, data cleaning, and visualization.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |Presentation Skills, Microsoft Office, Information and Communications Technology (ICT), Product Optimization, Marketing Data Analysis, Performance Improvement, Conflict Management, Fundamentals, Relational Databases, Tableau, Real-time Control, Easily Adaptable, Building Analysis, Deep Packet Inspection, Reporting Metrics, Work Simplification, Database Modeling, Apache Spark, Simplifying the Complex, Microsoft Power BI, Problem Solving, Dashboard Metrics, Supporting Others, Overtime, Excel Formulas, Python (Programming Language), Big Data, KPI Reporting, Organization Skills, Certified Public Accounting, Data Structures, Database Design, Operational Analysis, Data Modeling, Workflow Automation, Identifying Trends, Interactive Displays, Italian, Data Analysis, Communication, Data Cleaning, VLOOKUP, Excel Pivot, Client Analysis, Visualization, Microsoft PowerPoint, Time Management, Excel Dashboards, Data Reporting, Data Storage, Laptop Sales, Portuguese, Microsoft Power Query, Programming Languages, Campaign Performance Analysis, Summarizing Information, Statistical Concepts, Formulation, Hadoop, HR Analytics, New Product Implementations, Object-Oriented Programming (OOP), Information Technology Training, Data Processing, تحليل البيانات, تقرير البيانات|NULL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |Faculty of Computers and Information tanta university  | Tanta University | Tanta University | Tanta University - Computer science  | جامعه طنطا - Student of computer science             |907             |879             |https://media.licdn.com/dms/image/v2/D4E04AQEACjRSg_eGeg/profile-originalphoto-shrink_900_1200/B4EZpQZM.eHgAI-/0/1762285377149?e=1765411200&v=beta&t=6a2ttJV8hYKewc5HDeQqqyRzLfLeQgAFv26JnxYdhvc                      |https://media.licdn.com/dms/i ...
# |Mohamed Elbasuoney|Mohamed Elbasuoney|melbasuoney@gmail.com   |Statistical Analyst @ GOTHI | Youth Ambassador @ IOM | Data Analyst | ITI | Research | ALX | Digital Health | Climate Advocate                                                           |As a dedicated Data Analyst and Clinical Research Statistical Analyst, I specialize in transforming complex healthcare and medical data into actionable insights that drive impactful research. With a solid foundation in biostatistics, I leverage tools such as SPSS, R, Python, and SQL to provide accurate statistical analysis and support data-driven decisions in medical research.  I hold a Bachelor’s in Clinical Pharmacy and a Diploma in Health Information Technology, combining my expertise in healthcare with advanced analytical skills. My experience at the Research Support Center (RSC) has honed my abilities in collaborating with researchers, performing data analysis, and guiding the collection and interpretation of data for clinical studies.  I am passionate about health data science and continuously advancing my technical capabilities in data engineering and health informatics. Let's connect if you’re looking for a data-driven professional to support your healthcare research, or if you’re interested in exploring opportunities in health data analytics.                                                                                                                                                                                                                                                                                                 |Generative AI, Large Language Models (LLM), Machine Learning, Cloud Computing, Communication, English, Culture Change, Climate Change, Youth Activism, Youth Outreach, Youth Participation, SQL, Tableau, IBM SPSS, Amazon Web Services (AWS), R (Programming Language), Python (Programming Language), Data Analysis, Microsoft Excel, Statistical Data Analysis, Statistical Research                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |AWS Certified Cloud Practitioner | Maharatech Database fundamentals | Data Fundamentals | AI Masterclass for healthcare professionals programme | Green Digital Certificate  | McKinsey Forward Program | Excel Fundamentals | Nanodegree, Business Analytics & Digital Freelancing  | Data Analysis with Excel Power Tools |  Data Analyst Specialist | Volunteer | AI and Digital Transformation Ambassadors | Google Data Analytics Professional Certificate | Global Circles | Introducing Generative AI with AWS | AWS Educate Machine Learning Foundations | Professional Development Skills for the Digital Age | Data Analysis in Healthcare | Microsoft PL300 Exam Prep|Information Technology Institute (ITI) | Udacity - Nanodegree | Health information technology & statitics training center - Diploma of Education | Damanhour University - Bachelor's degree|1174            |364             |https://media.licdn.com/dms/image/v2/D4D04AQHnibNjP1Em7A/profile-originalphoto-shrink_900_1200/profile-originalphoto-shrink_900_1200/0/1731011376131?e=1765411200&v=beta&t=3NDTCyYkKDFNVWkCkYFXOaJwBdbl5Cyd_wZogNE6-sQ|https://media.licdn.com/dms/i ...
# +------------------+------------------+------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------- ...
#
#
# LinkedProfiles table saved successfully!
